# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import yfinance as yf

# %%
df = yf.download('RELIANCE.NS', start="2019-01-01", end="2024-01-01")
# Out:
# /tmp/ipykernel_6659/3690777118.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('RELIANCE.NS', start="2019-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1235 entries, 2019-01-01 to 2023-12-29
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Close, RELIANCE.NS)   1235 non-null   float64
#  1   (High, RELIANCE.NS)    1235 non-null   float64
#  2   (Low, RELIANCE.NS)     1235 non-null   float64
#  3   (Open, RELIANCE.NS)    1235 non-null   float64
#  4   (Volume, RELIANCE.NS)  1235 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 57.9 KB

# %%
df.shape
# Out:
# (1235, 5)

# %%
df.size
# Out:
# 6175

# %%
df.isna().sum()
# Out:
# Price   Ticker
# Close   RELIANCE.NS    0
# High    RELIANCE.NS    0
# Low     RELIANCE.NS    0
# Open    RELIANCE.NS    0
# Volume  RELIANCE.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS   RELIANCE.NS
# count   1235.000000  1235.000000  1235.000000  1235.000000  1.235000e+03
# mean     932.740873   943.309532   923.046944   933.552059  2.079654e+07
# std      239.357952   240.454122   238.172502   239.354777  1.611350e+07
# min      393.662384   423.029534   389.921900   407.978572  1.705656e+06
# 25%      684.072144   690.206025   677.960452   686.184966  1.131555e+07
# 50%      993.905579  1006.498099   982.825062   996.419281  1.593215e+07
# 75%     1139.139160  1148.213302  1129.976686  1139.140623  2.395899e+07
# max     1291.324341  1297.754090  1278.013265  1293.601441  1.426834e+08

# %%
df.columns = df.columns.droplevel(1)

# %%
df.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2019-01-01  496.196350  498.985004  491.371623  498.077593   9746670
# 2019-01-02  489.733887  498.852220  487.343625  493.319235  15628818
# 2019-01-03  483.691956  493.363572  482.518971  490.220847  16288287
# 2019-01-04  486.303467  488.870779  478.535197  485.750186  18516544
# 2019-01-07  489.003540  495.067675  487.343638  489.999475  12060290

# %%
df.corr(numeric_only=True)
# Out:
# Price      Close      High       Low      Open    Volume
# Price
# Close   1.000000  0.999315  0.999257  0.998204 -0.319510
# High    0.999315  1.000000  0.998915  0.999126 -0.306533
# Low     0.999257  0.998915  1.000000  0.999127 -0.334822
# Open    0.998204  0.999126  0.999127  1.000000 -0.322679
# Volume -0.319510 -0.306533 -0.334822 -0.322679  1.000000

# %%
sns.heatmap(df.corr(), cmap='Reds', annot=True)
# Out:
# <Axes: xlabel='Price', ylabel='Price'>

# %% [markdown]
# **Here we can observe that all the columns have almost same relation with each other, apart form the volume column**

# %%
df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %% [markdown]
# #Closing Price

# %%
df['Close'].plot(kind='line')
plt.title("Closing Price over the years", y=1.01)
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# **Here we can observe that there's a dip in shares price in the first quarter of 2020 mainly because of COVID-19, then there's is drastic increment.**

# %% [markdown]
# ### 2019

# %%
df[df.index.year == 2019]['Close'].plot(kind='line')
plt.title("Closing Price in 2019", y=1.01)
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# ### 2020

# %%
df[df.index.year == 2020]['Close'].plot(kind='line')
plt.title("Closing Price in 2020")
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# ### 2021

# %%
df[df.index.year == 2021]['Close'].plot(kind='line')
plt.title("Closing Price in 2021")
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# ### 2022

# %%
df[df.index.year == 2022]['Close'].plot(kind='line')
plt.title("Closing Price in 2022")
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# ### 2023

# %%
df[df.index.year == 2023]['Close'].plot(kind='line')
plt.title("Closing Price in 2023")
plt.xlabel("Years")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %% [markdown]
# # Volume

# %%
sns.histplot(df['Volume'], bins=50, kde=True)
# Out:
# <Axes: xlabel='Volume', ylabel='Count'>

# %%
df['Volume'].plot(kind='line')
plt.title("Volume over the years", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# Here we can observe that the volume spikes in between, but in 2020 we can see multile spikes, as we observed above that the prices went down in 2020, which means people might have sold their stocks and volume spiked.

# %% [markdown]
# ### 2019

# %%
df[df.index.year == 2019]['Volume'].plot(kind='line')
plt.title("Volume in 2019", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ### 2020

# %%
df[df.index.year == 2020]['Volume'].plot(kind='line')
plt.title("Volume in 2020", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ### 2021

# %%
df[df.index.year == 2021]['Volume'].plot(kind='line')
plt.title("Volume in 2021", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ### 2022

# %%
df[df.index.year == 2022]['Volume'].plot(kind='line')
plt.title("Volume in 2022", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ### 2023

# %%
df[df.index.year == 2023]['Volume'].plot(kind='line')
plt.title("Volume in 2023", y=1.01)
plt.xlabel("Years")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# #Features

# %%
df['ma_7'] = df['Close'].rolling(7).mean()
df['ma_21'] = df['Close'].rolling(21).mean()
df['Return'] = df['Close'].pct_change()
df['Volatility'] = df['Return'].rolling(7).std()

# %%
column = ['Close', 'ma_7', 'ma_21']
df[column].plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### 2019

# %%
df[df.index.year == 2019][column].plot(kind='line')
plt.title("2019")
# Out:
# Text(0.5, 1.0, '2019')

# %% [markdown]
# ### 2020

# %%
df[df.index.year == 2020][column].plot(kind='line')
plt.title("2020")
# Out:
# Text(0.5, 1.0, '2020')

# %% [markdown]
# ### 2021

# %%
df[df.index.year == 2021][column].plot(kind='line')
plt.title("2021")
# Out:
# Text(0.5, 1.0, '2021')

# %% [markdown]
# ### 2022

# %%
df[df.index.year == 2022][column].plot(kind='line')
plt.title("2022")
# Out:
# Text(0.5, 1.0, '2022')

# %% [markdown]
# ### 2023

# %%
df[df.index.year == 2023][column].plot(kind='line')
plt.title("2023")
# Out:
# Text(0.5, 1.0, '2023')

# %%
sns.histplot(df['Return'], bins=50, kde=True)
# Out:
# <Axes: xlabel='Return', ylabel='Count'>

# %% [markdown]
# # Making Target Column

# %%
df['Target'] = np.where(df['Return'].shift(-1) < 0, 0, 1)

# %%
df.shape
# Out:
# (1235, 10)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1215, 10)

# %% [markdown]
# #Model Training

# %%
df.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2019-01-29  535.878784  545.174197  531.762257  544.886461  20405845
# 2019-01-30  529.261414  542.230731  527.225281  537.804366  17164298
# 2019-01-31  543.182312  544.311034  531.607353  532.049978  22279301
# 2019-02-01  553.274353  555.509696  543.138014  546.214343  20187323
# 2019-02-04  571.400574  574.078542  549.777735  551.968757  25528059
#
# Price             ma_7       ma_21    Return  Volatility  Target
# Date
# 2019-01-29  545.885629  511.318803 -0.015372    0.021277       0
# 2019-01-30  543.229806  512.893329 -0.012349    0.011193       1
# 2019-01-31  542.723929  515.438493  0.026303    0.016332       1
# 2019-02-01  544.219387  518.751940  0.018579    0.017519       1
# 2019-02-04  546.966902  522.804183  0.032762    0.020388       1

# %%
from sklearn.model_selection import train_test_split

x = df[['ma_7', 'ma_21', 'Volatility', 'Return']]
y = df['Target']

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

models = {
    'Logistic Regression' : LogisticRegression(),
    'Decision Tree' : DecisionTreeClassifier(max_depth=5),
    'Random Forest' : RandomForestClassifier(n_estimators=100),
    'Gradient Boosting' : GradientBoostingClassifier()
}

# %% [markdown]
# ## Evaluation and Compare Models

# %%
from sklearn.metrics import confusion_matrix, classification_report

for name, model in models.items():
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)
  print(f"Model: {name}")
  print(classification_report(y_pred, y_test))
# Out:
# Model: Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.24      0.38      0.30        93
#            1       0.64      0.49      0.55       211
#
#     accuracy                           0.45       304
#    macro avg       0.44      0.43      0.43       304
# weighted avg       0.52      0.45      0.48       304
#
# Model: Decision Tree
#               precision    recall  f1-score   support
#
#            0       0.23      0.39      0.29        84
#            1       0.68      0.50      0.58       220
#
#     accuracy                           0.47       304
#    macro avg       0.46      0.45      0.43       304
# weighted avg       0.56      0.47      0.50       304
#
# Model: Random Forest
#               precision    recall  f1-score   support
#
#            0       0.36      0.39      0.38       133
#            1       0.50      0.47      0.48       171
#
#     accuracy                           0.43       304
# ...

# %% [markdown]
# On comparing among all the models we can observe that Gradient Boosting performs the best.

# %% [markdown]
# ## Normalising the Data

# %%
from sklearn.preprocessing import StandardScaler
features = ['Return', 'Volatility', 'ma_7']
scaler = StandardScaler()

# %%
from sklearn.cluster import KMeans

x_scaled = scaler.fit_transform(df[features])

kmeans = KMeans(n_clusters=3, random_state=42)
df['Clusters'] = kmeans.fit_predict(x_scaled)

# %%
df['Clusters']
# Out:
# Date
# 2019-01-29    2
# 2019-01-30    2
# 2019-01-31    2
# 2019-02-01    2
# 2019-02-04    2
#              ..
# 2023-12-22    0
# 2023-12-26    0
# 2023-12-27    0
# 2023-12-28    0
# 2023-12-29    0
# Name: Clusters, Length: 1215, dtype: int32

# %% [markdown]
# **Here the 3 clusters represent if the stocks goes up, down or stays neutral**

# %%
sns.scatterplot(x='Return', y='Volatility', hue='Clusters', data=df)
# Out:
# <Axes: xlabel='Return', ylabel='Volatility'>

# %% [markdown]
# ### Conclusion and Limitations:
# Gradient Boosting performed the best amongst all the models, However it only prdicts on the basis of historical data, it doen't know about the real life events like: Pandemics(Covid, Wars), Government policies(any change in taxation law or change in interest rates), Company-specific news(any product launch, earnings etc)
